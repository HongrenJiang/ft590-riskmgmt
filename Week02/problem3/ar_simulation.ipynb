# %%
# import the module for simulating data
import numpy as np
from matplotlib import pyplot as plt
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
# Plot 1: AR(1)
plt.figure(figsize=(6,2))
ar1 = np.array([1, -0.9])
ma1 = np.array([1])
AR_object1 = ArmaProcess(ar1, ma1)
simulated_data_1 = AR_object1.generate_sample(nsample=1000)
plt.plot(simulated_data_1)
plot_acf(simulated_data_1, alpha=1, lags=20)
plot_pacf(simulated_data_1, alpha=1, lags=20)
plt.show()

# %%
# Plot 2: AR(2)
plt.figure(figsize=(6,2))
ar2 = np.array([1, 0.9, 0.8])
ma2 = np.array([1])
AR_object1 = ArmaProcess(ar2, ma2)
simulated_data_2 = AR_object1.generate_sample(nsample=1000)
plt.plot(simulated_data_2)
plot_acf(simulated_data_2, alpha=1, lags=20)
plot_pacf(simulated_data_2, alpha=1, lags=20)
plt.show()

# %%
# Plot 3: AR(3)
plt.figure(figsize=(6,2))
ar3 = np.array([1, 0.9, 0.8, 0.7])
ma3 = np.array([1])
AR_object1 = ArmaProcess(ar3, ma3)
simulated_data_3 = AR_object1.generate_sample(nsample=1000)
plt.plot(simulated_data_3)
plot_acf(simulated_data_3, alpha=1, lags=20)
plot_pacf(simulated_data_3, alpha=1, lags=20)
plt.show()
